# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Flatten , Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(x_train , y_train), (x_test , y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
x_train , x_test = x_train/255.0 , x_test/255.0

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test , 10)

# %%
model = Sequential([
    Conv2D(32,(3,3),activation= "relu",input_shape=(32,32,3)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3),activation= 'relu'),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3),activation = 'relu'),
    Flatten(),
    Dense(512, activation = 'relu'),
    Dense(10,activation = 'softmax') #10 classes for CIFAR-10
])

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['accuracy']
)
history = model.fit(
    x_train,y_train,
    epochs=10,
    validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 57ms/step - accuracy: 0.3992 - loss: 1.6224 - val_accuracy: 0.6295 - val_loss: 1.0402
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 55ms/step - accuracy: 0.6384 - loss: 1.0229 - val_accuracy: 0.6702 - val_loss: 0.9273
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 54ms/step - accuracy: 0.7130 - loss: 0.8200 - val_accuracy: 0.7041 - val_loss: 0.8536
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 54ms/step - accuracy: 0.7642 - loss: 0.6756 - val_accuracy: 0.7105 - val_loss: 0.8570
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 54ms/step - accuracy: 0.8082 - loss: 0.5437 - val_accuracy: 0.7071 - val_loss: 0.8847
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 55ms/step - accuracy: 0.8506 - loss: 0.4280 - val_accuracy: 0.7138 - val_loss: 0.9276
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 55ms/step - accuracy: 0.8880 - loss: 0.3131 - val_accuracy: 0.7171 - val_loss: 0.9895
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 54ms/step - accuracy: 0.9218 - loss: 0.2206 - val_accuracy: 0.7065 - val_loss: 1.1927
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 54ms/step - accuracy: 0.9427 - loss: 0.1666 - val_accuracy: 0.7052 - val_loss: 1.2978
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 142s 55ms/step - accuracy: 0.9559 - loss: 0.1289 - val_accuracy: 0.7185 - val_loss: 1.4029

# %%
loss, accuracy = model.evaluate(x_test,y_test)
print(f"Test loss : {loss: .4f}")
print(f"Test accuracy : {accuracy: .4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7195 - loss: 1.3788
# Test loss :  1.4029
# Test accuracy :  0.7185
